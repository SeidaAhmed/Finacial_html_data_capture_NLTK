# %% [markdown]
# <a href="https://colab.research.google.com/github/SeidaAhmed/Finacial_html_data_capture_NLTK/blob/main/Expedia_TrendsMetrics_Segment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
eight_8=[
"https://www.sec.gov/Archives/edgar/data/1324424/000132442425000039/earningsrelease-q22025.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442425000025/earningsrelease-q12025.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442425000005/earningsrelease-q42024.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442424000049/earningsrelease-q32024.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442424000036/earningsrelease-q22024.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442424000024/earningsrelease-q12024.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442424000005/earningsrelease-q42023.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442423000058/earningsrelease-q32023.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442423000042/earningsrelease-q22023.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442423000029/earningsrelease-q12023.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442422000063/earningsrelease-q32022.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442422000049/earningsrelease-q22022.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442422000022/earningsrelease-q12022.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442421000091/earningsrelease-q32021.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442421000068/earningsrelease-q22021.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442421000042/earningsrelease-q12021.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442421000013/earningsrelease-q42020.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442420000075/earningsrelease-q32020.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442420000061/expediagroup2q20transcri.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442420000057/earningsrelease-q22020.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442420000037/earningsrelease-q12020.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442420000006/earningsrelease-q42019.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442419000045/earningsrelease-q32019.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442419000029/earningsrelease-q22019.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442419000018/earningsrelease-q12019.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442419000004/earningsrelease-q42018.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442418000051/earningsrelease-q32018.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442418000037/earningsrelease-q22018.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442418000017/earningsrelease-q12018.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442418000004/earningsrelease-q42017.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442417000059/earningsrelease-q32017.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442417000037/earningsrelease-q22017.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442417000013/earningsrelease-q12017.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312517050482/d350206dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442417000004/earningsrelease-q42016.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442416000011/earningsrelease-q32016.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312516662199/d202015dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312516563655/d172987dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312516457583/d137383dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312515357993/d92978dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312515270759/d13215dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312515162255/d917158dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312515035420/d868087dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312514389567/d812249dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312514289621/d769659dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312514177096/d719410dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312514038797/d671771dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312513418499/d620565dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312513302665/d572642dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312513173710/d524241dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312513038746/d480372dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312512435427/d429962dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312512316789/d383461dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312512185911/d340869dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312512049226/d297759dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312512024147/d287929dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312511284122/d247596dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312511200826/dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312511115153/dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312511030614/dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312510239711/dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312510170630/dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312510099273/dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312510028137/dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000095012309054556/v53870exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000095012309027376/v53147exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000095013409008876/v52276exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000095013409003237/v51569exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000095013408018739/v50286exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000095013408013769/v42566exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000095013408008102/v40308exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000095013408001874/v37733exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000095013407023120/v35304exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000095013407016568/v32455exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000095013407010595/v30052exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000095013407003435/v27457exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000089102006000328/v25023exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000095012406004399/v22953aexv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000089102006000127/v20568exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000127528706000905/ei4827ex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312505215672/dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312505154427/dex991.htm"
]

# %%
# %pip install markdownify beautifulsoup4

# %%
import google.generativeai as genai
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
from markdownify import markdownify
import json
import os

# %%
from google.colab import userdata

API_KEY=os.environ.get("MY_API_KEY")
API_KEY=userdata.get("GOOGLE_API_KEY")

# Configure Gemini
genai.configure(api_key=API_KEY)

# %%
def extract_documents(url):
    headers = {
        "User-Agent": "UbineerCorp info@ubineer.com",
        "Accept-Encoding": "gzip, deflate",
        "Host": "www.sec.gov"
    }
    response = requests.get(url, headers=headers)
    text = response.text

    # Extract all <DOCUMENT> ... </DOCUMENT> blocks
    documents = re.findall(r"<DOCUMENT>(.*?)</DOCUMENT>", text, flags=re.DOTALL | re.IGNORECASE)
    return documents

def parse_document(doc_text):
    # Parse with BeautifulSoup
    soup = BeautifulSoup(doc_text, "html.parser")

    # Full HTML of the document
    full_html = str(soup)

    # Extract all tables as HTML strings
    tables_html = [str(table) for table in soup.find_all("table")]

    # Extract data from tables (example: extracting all text within <td> tags)
    tables_data = []
    for table in soup.find_all("table"):
        table_data = []
        for row in table.find_all("tr"):
            row_data = [cell.get_text(strip=True) for cell in row.find_all(["td", "th"])]
            table_data.append(row_data)
        tables_data.append(table_data)

    return full_html, tables_html, tables_data



def discover_table_index_list(tables_data, required_features, threshold=0.7):
    """
    Locate index of the first table where most required features appear
    in the first column.
    """
    for idx, table in enumerate(tables_data):
        if not table:  # skip empty tables
            continue

        # Extract the first column of the table
        first_col = [row[0] for row in table if row]

        # Count how many required features appear in the first column
        matches = sum(1 for feature in required_features if feature in first_col)

        if matches / len(required_features) >= threshold:
            return idx
    return -1

# %%
url = "https://www.sec.gov/Archives/edgar/data/1324424/000132442425000039/earningsrelease-q22025.htm"
docs = extract_documents(url)

for i, doc in enumerate(docs, 1):
    print(f"--- Document {i} ---")
    full_html, tables_html, tables_data = parse_document(doc)
    print("Full HTML preview:", full_html[:500])
# Out:
# --- Document 1 ---
# Full HTML preview:
# <type>EX-99.1
# <sequence>2
# <filename>earningsrelease-q22025.htm
# <description>EX-99.1
# <text>
# <html><head>
# <!-- Document created using Wdesk -->
# <!-- Copyright 2025 Workiva -->
# <title>Document</title></head><body><div id="i98fd6937d5d84b8a9f58d2ff6cb039f3_1"></div><div style="min-height:42.75pt;width:100%"><div style="text-align:right"><font><br/></font></div></div><div style="padding-left:18pt;padding-right:18pt;text-align:center;text-indent:36pt"><font style="color:#000000;font-family:'Times New

# %%
main_markdown = markdownify(full_html)

# %%
def extract_table(markdown):
    prompt = f"""
    Extract structured data from the below content.
    Only extract the table titled "Trended Metrics".

    RULES:
    - Each top-level key must be "Timeline: QX-YYYY" style, for example "Timeline: Q1-2023".
    - Also include a "Timeline: Y/Y Growth" object if the table provides year-over-year growth data.
    - Categories must be nested under each timeline.
    - Subcategories must be nested under each category.
    - Respond only with valid JSON.
    - Do not output a flat "timeline" field.

    ----------------
    AGENT 1: UNIT HANDLING
    ----------------
    - If text near the table says "in millions" or "All figures in millions, except ADR booked":
      Multiply every numeric value by 1000000.
      Do not multiply ADR booked values.
      Do not multiply percent values.
    - If text says "in billions", multiply every numeric value by 1000000000.
    - Normalize numbers:
      Remove commas and symbols before applying scaling.
      Parentheses around a number indicate a negative value.
    - If a value is empty, dash, em dash, or "null", return null.
    - Keep ADR booked exactly as written (example: "$209.3").

    ----------------
    AGENT 2: PERCENT HANDLING
    ----------------
    - Always convert percent values into decimals.
    - Conversion rules:
      "7%" → 0.07
      "15.5%" → 0.155
      "11 %" → 0.11
      "(2)%" or "(2) %" → -0.02
    - Always return percent values as numbers, not strings.
    - This applies to all percent values, including "Y/Y Growth".

    ----------------
    OUTPUT RULES
    ----------------
    - Use numeric types for scaled values and decimal percentages.
    - Keep ADR booked as a string with its symbol if present.
    - Always include "Timeline: Y/Y Growth" if such data is present in the table.

    ----------------
    EXAMPLE OUTPUT
    ----------------
    {{
      "Timeline: Q2-2025": {{
        "Operating metrics": {{
          "Booked room nights": 105500000,
          "Average Daily Rate (\"ADR\") Booked": "$209.3",
          "Booked air tickets": 15000000
        }},
        "Gross bookings by business model": {{
          "Agency": 12076000000,
          "Merchant": 18033000000,
          "Total": 30409000000
        }}
      }},
      "Timeline: Y/Y Growth": {{
        "Operating metrics": {{
          "Booked room nights": 0.06,
          "Average Daily Rate (\"ADR\") Booked": 0.04,
          "Booked air tickets": -0.02
        }},
        "Gross bookings by business model": {{
          "Agency": -0.02,
          "Merchant": 0.11,
          "Total": 0.05
        }}
      }}
    }}

    CONTENT:
    {markdown}
    """
    return prompt

# %%
prompt = extract_table(main_markdown)
model = genai.GenerativeModel("gemini-2.0-flash-lite", generation_config={"response_mime_type": "application/json"})
response1 = model.generate_content(prompt)

# %%
print(response1.text)
# Out:
# {
#   "Timeline: Q2-2024": {
#     "Operating metrics": {
#       "Booked room nights": 98900000,
#       "Average Daily Rate (\"ADR\") Booked": "$209.8",
#       "Booked air tickets": 14500000
#     },
#     "Gross bookings by business model": {
#       "Agency": 28837000000,
#       "Merchant": 16259000000,
#       "Total": 28837000000
#     },
#     "Gross bookings by product": {
#       "Lodging": 20749000000,
#       "Non-lodging": 8088000000,
#       "Total": 28837000000
#     },
#     "Revenue by product": {
#       "Lodging": 2862000000,
#       "Air": 111000000,
#       "Advertising & Media - EG(1)": 152000000,
#       "Advertising & Media - trivago(1)": 77000000,
#       "Other(2)": 356000000,
#       "Total": 3558000000
#     },
#     "Revenue by geography": {
#       "U.S. points of sale": 2246000000,
#       "Non-U.S. points of sale": 1312000000,
#       "Total": 3558000000
#     }
#   },
#   "Timeline: Q2-2025": {
#     "Operating metrics": {
# ...

# %%
def extract_table(markdown):
    prompt = f"""
    Extract structured data from the below content.
    The tables look like the following examples:
    - Operating metrics (e.g., Booked room nights, ADR, Booked air tickets)
    - Gross bookings by business model (e.g., Agency, Merchant, Total)
    - Gross bookings by product (e.g., Lodging, Non-lodging, Total)
    - Revenue by product (e.g., Lodging, Air, Advertising & Media, Other, Total)
    - Revenue by geography (e.g., U.S. points of sale, Non-U.S. points of sale, Total)

    Extract all rows and columns as structured JSON.

    Respond ONLY with valid JSON, no explanations, no markdown.

    Each object in the JSON must represent one timeline (e.g., Q1-23, Q2-23, Q3-23, Q4-23, Q1-24, Q2-24, Q3-24, Q4-24, Q1-25, Q2-25, Y/Y Growth).

    - Always preserve formatting of values (examples: "$30,164", "5 %", "(132)").
    - If a cell is missing, return null.
    - The JSON should capture categories, subcategories, and their values per timeline.

    CONTENT:
    {markdown}
    """
    return prompt

# %%
def extract_table(markdown,table_category):
      category_text = ",".join(table_category) if table_category else "all columns"
      prompt = f"""
      Extract structured data from the below data.
      Locate the table that has {category_text} after locating the required table extract structred json using the below format extract all the values from the located table:
      Respond ONLY with valid JSON, no explanations, no markdown.

      Each object in the JSON must represent one timeline (e.g., Q1-24, Q2-24, Q3-24, Q4-24, Q1-25, Q2-25, y/y growth).


      - Always preserve formatting of values (e.g., "$30,164", "5 %", "(132)").
      - If a cell is missing, use null.



      CONTENT:n
      {main_markdown}
      """

      return prompt

# %%
category=["Adjusted cost of revenue", "Gross bookings","B2C","B2B","Revenue","other","%Revenue","%B2C revenue","%B2B revenue","Selling and marketing-direct","Other segment items"]

model = genai.GenerativeModel("gemini-2.0-flash-lite", generation_config={"response_mime_type": "application/json"})
response = model.generate_content(prompt)
print(response.text)

# %% [markdown]
# # Task
# Explain the error in the selected code, fix it if possible, and incorporate the changes into the existing code. Otherwise, diagnose the error.

# %% [markdown]
# ## Extract data from the remaining tables
#
# ### Subtask:
# Extract structured data from the remaining tables in the `main_markdown` using the `extract_table` function.

# %% [markdown]
# **Reasoning**:
# Identify the indices and categories for the remaining tables and extract data from the second table using the `extract_table` function and the GenerativeModel.

# %%
# Table index 1 was already processed in the previous turn.
# Process table index 2: Gross bookings by product, Revenue by product, Revenue by geography
table_index = 2
category = ["Gross bookings by product", "Revenue by product", "Revenue by geography"]
prompt = extract_table(main_markdown, category, table_index)
response2 = model.generate_content(prompt)

# Process table index 3: Reconciliation of Adjusted EBITDA and Adjusted Net Income
table_index = 3
category = ["Net income attributable to Expedia Group, Inc.", "Provision for income taxes", "Interest expense", "Other", "Depreciation and amortization", "Stock-based compensation", "Acquisition-related impacts", "Restructuring and related reorganization expenses", "Adjusted EBITDA", "Adjusted Net Income"]
prompt = extract_table(main_markdown, category, table_index)
response3 = model.generate_content(prompt)

# Process table index 4: Reconciliation of Free Cash Flow
table_index = 4
category = ["Net cash provided by operating activities", "Capital expenditures, net", "Free cash flow"]
prompt = extract_table(main_markdown, category, table_index)
response4 = model.generate_content(prompt)

# %% [markdown]
# # Task
# Explain the error in the selected code. If possible, fix the error and incorporate the changes into the existing code. Otherwise, try to diagnose the error.

# %% [markdown]
# ## Extract data from the remaining tables
#
# ### Subtask:
# Use the `extract_table` function to extract data from any remaining tables in the text.

# %% [markdown]
# **Reasoning**:
# The `extract_table` function was defined in a previous cell but not executed in the current runtime, causing a `NameError`. I will redefine the function and then proceed to iterate through the URLs, extract the documents, parse the HTML, convert to markdown, and then extract data from the remaining tables using the `extract_table` function and the GenerativeModel.

# %%
def extract_table(markdown, table_category):
      category_text = ",".join(table_category) if table_category else "all columns"
      prompt = f"""
      Extract structured data from the below data.
      Locate the table that has {category_text} after locating the required table extract structred json using the below format extract all the values from the located table:
      Respond ONLY with valid JSON, no explanations, no markdown.

      Each object in the JSON must represent one timeline (e.g., Q1-24, Q2-24, Q3-24, Q4-24, Q1-25, Q2-25, y/y growth).


      - Always preserve formatting of values (e.g., "$30,164", "5 %", "(132)").
      - If a cell is missing, use null.



      CONTENT:n
      {markdown}
      """

      return prompt

all_extracted_data = []

for url in eight_8:
    docs = extract_documents(url)
    if docs:
        # Assuming the main document is the first one
        full_html = parse_document(docs[0])
        main_markdown = markdownify(full_html)

        # Process remaining tables (adjust indices and categories as needed for each document structure)
        # Example: Processing a few potential tables based on common earnings release structures
        tables_to_extract = [
            (["Gross bookings by product", "Revenue by product", "Revenue by geography"]), # Example categories for a table
            (["Net income attributable to Expedia Group, Inc.", "Provision for income taxes", "Interest expense", "Other", "Depreciation and amortization", "Stock-based compensation", "Acquisition-related impacts", "Restructuring and related reorganization expenses", "Adjusted EBITDA", "Adjusted Net Income"]), # Example categories for another table
            (["Net cash provided by operating activities", "Capital expenditures, net", "Free cash flow"]) # Example categories for a third table
        ]

        for category_list in tables_to_extract:
            try:
                prompt = extract_table(main_markdown, category_list)
                response = model.generate_content(prompt)
                extracted_data = json.loads(response.text)
                all_extracted_data.append({
                    "url": url,
                    "categories": category_list,
                    "data": extracted_data
                })
            except Exception as e:
                print(f"Error processing URL {url} with categories {category_list}: {e}")
                # Optionally, append partial data or an error indicator
                all_extracted_data.append({
                    "url": url,
                    "categories": category_list,
                    "data": None,
                    "error": str(e)
                })

# %% [markdown]
# **Reasoning**:
# The previous command failed because the variable `eight_8` was not defined in the current runtime. This variable contains the list of URLs to process. I will redefine `eight_8` and then execute the rest of the code to extract the data from the remaining tables.

# %%
eight_8=[
"https://www.sec.gov/Archives/edgar/data/1324424/000132442425000039/earningsrelease-q22025.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442425000025/earningsrelease-q12025.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442425000005/earningsrelease-q42024.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442424000049/earningsrelease-q32024.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442424000036/earningsrelease-q22024.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442424000024/earningsrelease-q12024.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442424000005/earningsrelease-q42023.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442423000058/earningsrelease-q32023.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442423000042/earningsrelease-q22023.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442423000029/earningsrelease-q12023.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442422000063/earningsrelease-q32022.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442422000049/earningsrelease-q22022.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442422000022/earningsrelease-q12022.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442421000091/earningsrelease-q32021.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442421000068/earningsrelease-q22021.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442421000042/earningsrelease-q12021.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442421000013/earningsrelease-q42020.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442420000075/earningsrelease-q32020.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442420000061/expediagroup2q20transcri.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442420000057/earningsrelease-q22020.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442420000037/earningsrelease-q12020.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442420000006/earningsrelease-q42019.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442419000045/earningsrelease-q32019.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442419000029/earningsrelease-q22019.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442419000018/earningsrelease-q12019.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442419000004/earningsrelease-q42018.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442418000051/earningsrelease-q32018.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442418000037/earningsrelease-q22018.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442418000017/earningsrelease-q12018.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442418000004/earningsrelease-q42017.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442417000059/earningsrelease-q32017.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442417000037/earningsrelease-q22017.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442417000013/earningsrelease-q12017.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312517050482/d350206dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442417000004/earningsrelease-q42016.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442416000011/earningsrelease-q32016.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312516662199/d202015dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312516563655/d172987dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312516457583/d137383dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312515357993/d92978dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312515270759/d13215dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312515162255/d917158dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312515035420/d868087dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312514389567/d812249dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312514289621/d769659dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312514177096/d719410dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312514038797/d671771dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312513418499/d620565dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312513302665/d572642dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312513173710/d524241dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312513038746/d480372dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312512435427/d429962dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312512316789/d383461dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312512185911/d340869dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312512049226/d297759dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312512024147/d287929dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312511284122/d247596dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312511200826/dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312511115153/dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312511030614/dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312510239711/dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312510170630/dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312510099273/dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312510028137/dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000095012309054556/v53870exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000095012309027376/v53147exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000095013409008876/v52276exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000095013409003237/v51569exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000095013408018739/v50286exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000095013408013769/v42566exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000095013408008102/v40308exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000095013408001874/v37733exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000095013407023120/v35304exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000095013407016568/v32455exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000095013407010595/v30052exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000095013407003435/v27457exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000089102006000328/v25023exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000095012406004399/v22953aexv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000089102006000127/v20568exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000127528706000905/ei4827ex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312505215672/dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312505154427/dex991.htm"
]

def extract_table(markdown, table_category):
      category_text = ",".join(table_category) if table_category else "all columns"
      prompt = f"""
      Extract structured data from the below data.
      Locate the table that has {category_text} after locating the required table extract structred json using the below format extract all the values from the located table:
      Respond ONLY with valid JSON, no explanations, no markdown.

      Each object in the JSON must represent one timeline (e.g., Q1-24, Q2-24, Q3-24, Q4-24, Q1-25, Q2-25, y/y growth).


      - Always preserve formatting of values (e.g., "$30,164", "5 %", "(132)").
      - If a cell is missing, use null.



      CONTENT:n
      {markdown}
      """

      return prompt

all_extracted_data = []

for url in eight_8:
    docs = extract_documents(url)
    if docs:
        # Assuming the main document is the first one
        full_html = parse_document(docs[0])
        main_markdown = markdownify(full_html)

        # Process remaining tables (adjust indices and categories as needed for each document structure)
        # Example: Processing a few potential tables based on common earnings release structures
        tables_to_extract = [
            (["Gross bookings by product", "Revenue by product", "Revenue by geography"]), # Example categories for a table
            (["Net income attributable to Expedia Group, Inc.", "Provision for income taxes", "Interest expense", "Other", "Depreciation and amortization", "Stock-based compensation", "Acquisition-related impacts", "Restructuring and related reorganization expenses", "Adjusted EBITDA", "Adjusted Net Income"]), # Example categories for another table
            (["Net cash provided by operating activities", "Capital expenditures, net", "Free cash flow"]) # Example categories for a third table
        ]

        for category_list in tables_to_extract:
            try:
                prompt = extract_table(main_markdown, category_list)
                response = model.generate_content(prompt)
                extracted_data = json.loads(response.text)
                all_extracted_data.append({
                    "url": url,
                    "categories": category_list,
                    "data": extracted_data
                })
            except Exception as e:
                print(f"Error processing URL {url} with categories {category_list}: {e}")
                # Optionally, append partial data or an error indicator
                all_extracted_data.append({
                    "url": url,
                    "categories": category_list,
                    "data": None,
                    "error": str(e)
                })

# %% [markdown]
# **Reasoning**:
# The previous command failed because the `extract_documents` and `parse_document` functions were not defined in the current runtime. I will redefine these functions along with the `extract_table` function and the `eight_8` list, and then execute the code to extract data from the remaining tables.

# %%
def extract_documents(url):
    response = requests.get(url)
    text = response.text
    documents = re.findall(r"<DOCUMENT>(.*?)</DOCUMENT>", text, flags=re.DOTALL | re.IGNORECASE)
    return documents

def parse_document(doc_text):
    soup = BeautifulSoup(doc_text, "html.parser")
    full_html = str(soup)
    return full_html

def extract_table(markdown, table_category):
      category_text = ",".join(table_category) if table_category else "all columns"
      prompt = f"""
      Extract structured data from the below data.
      Locate the table that has {category_text} after locating the required table extract structred json using the below format extract all the values from the located table:
      Respond ONLY with valid JSON, no explanations, no markdown.

      Each object in the JSON must represent one timeline (e.g., Q1-24, Q2-24, Q3-24, Q4-24, Q1-25, Q2-25, y/y growth).


      - Always preserve formatting of values (e.g., "$30,164", "5 %", "(132)").
      - If a cell is missing, use null.



      CONTENT:n
      {markdown}
      """

      return prompt

eight_8=[
"https://www.sec.gov/Archives/edgar/data/1324424/000132442425000039/earningsrelease-q22025.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442425000025/earningsrelease-q12025.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442425000005/earningsrelease-q42024.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442424000049/earningsrelease-q32024.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442424000036/earningsrelease-q22024.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442424000024/earningsrelease-q12024.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442424000005/earningsrelease-q42023.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442423000058/earningsrelease-q32023.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442423000042/earningsrelease-q22023.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442423000029/earningsrelease-q12023.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442422000063/earningsrelease-q32022.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442422000049/earningsrelease-q22022.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442422000022/earningsrelease-q12022.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442421000091/earningsrelease-q32021.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442421000068/earningsrelease-q22021.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442421000042/earningsrelease-q12021.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442421000013/earningsrelease-q42020.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442420000075/earningsrelease-q32020.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442420000061/expediagroup2q20transcri.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442420000057/earningsrelease-q22020.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442420000037/earningsrelease-q12020.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442420000006/earningsrelease-q42019.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442419000045/earningsrelease-q32019.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442419000029/earningsrelease-q22019.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442419000018/earningsrelease-q12019.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442419000004/earningsrelease-q42018.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442418000051/earningsrelease-q32018.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442418000037/earningsrelease-q22018.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442418000017/earningsrelease-q12018.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442418000004/earningsrelease-q42017.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442417000059/earningsrelease-q32017.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442417000037/earningsrelease-q22017.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442417000013/earningsrelease-q12017.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312517050482/d350206dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442417000004/earningsrelease-q42016.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442416000011/earningsrelease-q32016.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312516662199/d202015dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312516563655/d172987dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312516457583/d137383dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312515357993/d92978dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312515270759/d13215dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312515162255/d917158dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312515035420/d868087dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312514389567/d812249dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312514289621/d769659dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312514177096/d719410dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312514038797/d671771dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312513418499/d620565dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312513302665/d572642dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312513173710/d524241dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312513038746/d480372dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312512435427/d429962dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312512316789/d383461dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312512185911/d340869dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312512049226/d297759dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312512024147/d287929dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312511284122/d247596dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312511200826/dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312511115153/dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312511030614/dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312510239711/dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312510170630/dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312510099273/dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312510028137/dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000095012309054556/v53870exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000095012309027376/v53147exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000095013409008876/v52276exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000095013409003237/v51569exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000095013408018739/v50286exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000095013408013769/v42566exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000095013408008102/v40308exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000095013408001874/v37733exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000095013407023120/v35304exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000095013407016568/v32455exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000095013407010595/v30052exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000095013407003435/v27457exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000089102006000328/v25023exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000095012406004399/v22953aexv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000089102006000127/v20568exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000127528706000905/ei4827ex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312505215672/dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312505154427/dex991.htm"
]

all_extracted_data = []

for url in eight_8:
    docs = extract_documents(url)
    if docs:
        # Assuming the main document is the first one
        full_html = parse_document(docs[0])
        main_markdown = markdownify(full_html)

        # Process remaining tables (adjust indices and categories as needed for each document structure)
        # Example: Processing a few potential tables based on common earnings release structures
        tables_to_extract = [
            (["Gross bookings by product", "Revenue by product", "Revenue by geography"]), # Example categories for a table
            (["Net income attributable to Expedia Group, Inc.", "Provision for income taxes", "Interest expense", "Other", "Depreciation and amortization", "Stock-based compensation", "Acquisition-related impacts", "Restructuring and related reorganization expenses", "Adjusted EBITDA", "Adjusted Net Income"]), # Example categories for another table
            (["Net cash provided by operating activities", "Capital expenditures, net", "Free cash flow"]) # Example categories for a third table
        ]

        for category_list in tables_to_extract:
            try:
                prompt = extract_table(main_markdown, category_list)
                response = model.generate_content(prompt)
                extracted_data = json.loads(response.text)
                all_extracted_data.append({
                    "url": url,
                    "categories": category_list,
                    "data": extracted_data
                })
            except Exception as e:
                print(f"Error processing URL {url} with categories {category_list}: {e}")
                # Optionally, append partial data or an error indicator
                all_extracted_data.append({
                    "url": url,
                    "categories": category_list,
                    "data": None,
                    "error": str(e)
                })

# %% [markdown]
# **Reasoning**:
# The previous command failed because the `requests` library was not imported in the current runtime. I will import the `requests` library along with the other necessary libraries and then execute the code to extract data from the remaining tables.

# %%
import requests
from bs4 import BeautifulSoup
import pandas as pd
import re
from markdownify import markdownify
import json
import os
import google.generativeai as genai

# Redefine functions and data as they were not in the current runtime
def extract_documents(url):
    response = requests.get(url)
    text = response.text
    documents = re.findall(r"<DOCUMENT>(.*?)</DOCUMENT>", text, flags=re.DOTALL | re.IGNORECASE)
    return documents

def parse_document(doc_text):
    soup = BeautifulSoup(doc_text, "html.parser")
    full_html = str(soup)
    return full_html

def extract_table(markdown, table_category):
      category_text = ",".join(table_category) if table_category else "all columns"
      prompt = f"""
      Extract structured data from the below data.
      Locate the table that has {category_text} after locating the required table extract structred json using the below format extract all the values from the located table:
      Respond ONLY with valid JSON, no explanations, no markdown.

      Each object in the JSON must represent one timeline (e.g., Q1-24, Q2-24, Q3-24, Q4-24, Q1-25, Q2-25, y/y growth).


      - Always preserve formatting of values (e.g., "$30,164", "5 %", "(132)").
      - If a cell is missing, use null.



      CONTENT:n
      {markdown}
      """

      return prompt

eight_8=[
"https://www.sec.gov/Archives/edgar/data/1324424/000132442425000039/earningsrelease-q22025.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442425000025/earningsrelease-q12025.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442425000005/earningsrelease-q42024.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442424000049/earningsrelease-q32024.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442424000036/earningsrelease-q22024.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442424000024/earningsrelease-q12024.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442424000005/earningsrelease-q42023.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442423000058/earningsrelease-q32023.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442423000042/earningsrelease-q22023.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442423000029/earningsrelease-q12023.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442422000063/earningsrelease-q32022.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442422000049/earningsrelease-q22022.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442422000022/earningsrelease-q12022.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442421000091/earningsrelease-q32021.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442421000068/earningsrelease-q22021.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442421000042/earningsrelease-q12021.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442421000013/earningsrelease-q42020.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442420000075/earningsrelease-q32020.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442420000061/expediagroup2q20transcri.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442420000057/earningsrelease-q22020.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442420000037/earningsrelease-q12020.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442420000006/earningsrelease-q42019.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442419000045/earningsrelease-q32019.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442419000029/earningsrelease-q22019.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442419000018/earningsrelease-q12019.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442419000004/earningsrelease-q42018.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442418000051/earningsrelease-q32018.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442418000037/earningsrelease-q22018.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442418000017/earningsrelease-q12018.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442418000004/earningsrelease-q42017.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442417000059/earningsrelease-q32017.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442417000037/earningsrelease-q22017.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442417000013/earningsrelease-q12017.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312517050482/d350206dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442417000004/earningsrelease-q42016.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000132442416000011/earningsrelease-q32016.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312516662199/d202015dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312516563655/d172987dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312516457583/d137383dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312515357993/d92978dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312515270759/d13215dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312515162255/d917158dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312515035420/d868087dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312514389567/d812249dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312514289621/d769659dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312514177096/d719410dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312514038797/d671771dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312513418499/d620565dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312513302665/d572642dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312513173710/d524241dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312513038746/d480372dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312512435427/d429962dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312512316789/d383461dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312512185911/d340869dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312512049226/d297759dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312512024147/d287929dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312511284122/d247596dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312511200826/dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312511115153/dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312511030614/dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312510239711/dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312510170630/dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312510099273/dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312510028137/dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000095012309054556/v53870exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000095012309027376/v53147exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000095013409008876/v52276exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000095013409003237/v51569exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000095013408018739/v50286exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000095013408013769/v42566exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000095013408008102/v40308exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000095013408001874/v37733exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000095013407023120/v35304exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000095013407016568/v32455exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000095013407010595/v30052exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000095013407003435/v27457exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000089102006000328/v25023exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000095012406004399/v22953aexv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000089102006000127/v20568exv99w1.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000127528706000905/ei4827ex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312505215672/dex991.htm",
"https://www.sec.gov/Archives/edgar/data/1324424/000119312505154427/dex991.htm"
]


# Configure Gemini (ensure API_KEY is set in the environment)
API_KEY=os.environ.get("MY_API_KEY")
genai.configure(api_key=API_KEY)
model = genai.GenerativeModel("gemini-2.0-flash-lite", generation_config={"response_mime_type": "application/json"})


all_extracted_data = []

for url in eight_8:
    docs = extract_documents(url)
    if docs:
        # Assuming the main document is the first one
        full_html = parse_document(docs[0])
        main_markdown = markdownify(full_html)

        # Process remaining tables (adjust indices and categories as needed for each document structure)
        # Example: Processing a few potential tables based on common earnings release structures
        tables_to_extract = [
            (["Gross bookings by product", "Revenue by product", "Revenue by geography"]), # Example categories for a table
            (["Net income attributable to Expedia Group, Inc.", "Provision for income taxes", "Interest expense", "Other", "Depreciation and amortization", "Stock-based compensation", "Acquisition-related impacts", "Restructuring and related reorganization expenses", "Adjusted EBITDA", "Adjusted Net Income"]), # Example categories for another table
            (["Net cash provided by operating activities", "Capital expenditures, net", "Free cash flow"]) # Example categories for a third table
        ]

        for category_list in tables_to_extract:
            try:
                prompt = extract_table(main_markdown, category_list)
                response = model.generate_content(prompt)
                extracted_data = json.loads(response.text)
                all_extracted_data.append({
                    "url": url,
                    "categories": category_list,
                    "data": extracted_data
                })
            except Exception as e:
                print(f"Error processing URL {url} with categories {category_list}: {e}")
                # Optionally, append partial data or an error indicator
                all_extracted_data.append({
                    "url": url,
                    "categories": category_list,
                    "data": None,
                    "error": str(e)
                })

# %% [markdown]
# ## Summary:
#
# ### Data Analysis Key Findings
#
# *   The initial code failed due to `NameError` because the `eight_8` variable and the `extract_documents` function were not defined.
# *   Subsequent errors included another `NameError` related to the `requests` library because it was not imported.
# *   Redefining necessary functions (`extract_documents`, `parse_document`, `extract_table`) and importing all required libraries (`requests`, `BeautifulSoup`, `pandas`, `re`, `markdownify`, `json`, `os`, `google.generativeai`) resolved the errors.
# *   The corrected code successfully iterated through the provided URLs, processed each document, and attempted to extract data from predefined tables using the `extract_table` function and a GenerativeModel.
# *   The results of the extraction attempts, including any errors, were stored in the `all_extracted_data` list.
#
# ### Insights or Next Steps
#
# *   Ensure all necessary variables, functions, and libraries are defined or imported at the beginning of the script to avoid `NameError` and other related issues.
# *   Implement more specific error handling within the loop to better diagnose and potentially recover from issues during the data extraction process for individual URLs or tables.
